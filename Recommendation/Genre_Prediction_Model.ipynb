# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import spatial
import tensorflow as tf
from tensorflow.keras import layers,Sequential,regularizers

# %%
train=pd.read_csv("./input/train.csv")
test=pd.read_csv("./input/test.csv")
validation=pd.read_csv("./input/validation.csv")

# %%
def split_X_and_y(df,target):
    X=df.drop(columns=[target,"track","artist"])
    y=df[target]
    return X,y

# %%
X_train,y_train=split_X_and_y(train,"Song_Label")
X_test,y_test=split_X_and_y(test,"Song_Label")
X_val,y_val=split_X_and_y(validation,"Song_Label")

# %%
X_train
# Out:
#        danceability    energy       key  loudness      mode  speechiness  \
# 0          0.444581 -0.972723  1.638753 -0.793410 -1.503759    -0.463111
# 1         -0.479098  0.407024  1.072897  0.607076  0.665000    -0.370427
# 2          0.923317  0.744031  0.224112  0.849950  0.665000    -0.384330
# 3         -1.194386 -0.397828 -0.341745 -0.588437  0.665000    -0.482806
# 4          0.529064  0.248432  1.072897 -0.402888 -1.503759     0.440558
# ...             ...       ...       ...       ...       ...          ...
# 29042     -0.467833 -0.401793 -1.473458  0.746616  0.665000    -0.553478
# 29043      0.112282  0.157242 -0.341745  1.358138  0.665000    -0.376220
# 29044      0.382627  1.465623 -0.341745  0.780746 -1.503759     0.003784
# 29045     -0.608638  0.113630 -1.473458  0.036473  0.665000     0.103420
# 29046     -1.025420 -0.374040 -1.473458  0.154704  0.665000    -0.414452
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0          0.706359          0.194586 -0.552604  0.479628  0.111471
# 1         -1.073213         -0.507625 -0.228077 -0.972474  2.015245
# 2         -0.922656         -0.506242  0.925155  1.295500  0.023826
# 3         -1.022772          1.741131  0.386207 -1.818660  0.008743
# 4          1.167066         -0.199139 -0.309209 -0.542083 -0.708088
# ...             ...               ...       ...       ...       ...
# 29042      1.205459         -0.323456  2.263830  0.045495 -1.392829
# 29043      0.059596         -0.507785  0.264509  0.067950 -1.424472
# 29044     -1.076412          2.130240 -0.257053 -0.149117  0.709564
# 29045     -1.059451         -0.458655 -0.858587  0.412262  0.645865
# 29046     -0.079207         -0.507789  1.759654 -0.631903 -1.226128
#
#        duration_ms  time_signature  chorus_hit  sections    decade
# 0        -0.762637         0.25102    1.968211 -1.120657 -1.296824
# 1         0.299271         0.25102    0.054423  0.109963  0.416659
# 2        -0.627560         0.25102   -0.864662 -0.505347  1.558982
# 3         2.851622         0.25102   -0.165179  2.366100  0.987821
# 4         1.195979         0.25102    0.036170  0.315066  0.987821
# ...            ...             ...         ...       ...       ...
# 29042    -0.385169         0.25102   -0.407760  0.109963 -0.725663
# 29043    -0.103162         0.25102   -0.739306 -0.300244  1.558982
# 29044     0.815857         0.25102    0.126801  0.315066  1.558982
# 29045     0.084786         0.25102   -0.166743 -0.095140 -0.725663
# 29046     0.241477         0.25102   -0.778779  0.725273 -0.154502
#
# [29047 rows x 16 columns]

# %%
model=Sequential()
model.add(layers.Dense(90,input_shape=(X_train.shape[1],),activation="relu"))
model.add(layers.Dense(45,activation="relu"))
# model.add(layers.Dense(45,activation="relu"))
# model.add(layers.Dense(45,activation="relu"))
# model.add(layers.Dense(45,activation="relu"))
model.add(layers.Dense(9,activation="softmax"))

model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
history=model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=20)
# Out:
# Epoch 1/20
# 908/908 [==============================] - 3s 2ms/step - loss: 0.3241 - accuracy: 0.9059 - val_loss: 0.1287 - val_accuracy: 0.9546
# Epoch 2/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.1030 - accuracy: 0.9641 - val_loss: 0.0955 - val_accuracy: 0.9663
# Epoch 3/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0817 - accuracy: 0.9693 - val_loss: 0.0836 - val_accuracy: 0.9713
# Epoch 4/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0697 - accuracy: 0.9746 - val_loss: 0.0754 - val_accuracy: 0.9709
# Epoch 5/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0615 - accuracy: 0.9765 - val_loss: 0.0627 - val_accuracy: 0.9765
# Epoch 6/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0565 - accuracy: 0.9788 - val_loss: 0.0631 - val_accuracy: 0.9744
# Epoch 7/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0511 - accuracy: 0.9807 - val_loss: 0.0754 - val_accuracy: 0.9672
# Epoch 8/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0486 - accuracy: 0.9805 - val_loss: 0.0693 - val_accuracy: 0.9692
# Epoch 9/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0437 - accuracy: 0.9828 - val_loss: 0.0605 - val_accuracy: 0.9777
# Epoch 10/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0429 - accuracy: 0.9825 - val_loss: 0.0550 - val_accuracy: 0.9798
# Epoch 11/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0400 - accuracy: 0.9833 - val_loss: 0.0579 - val_accuracy: 0.9781
# Epoch 12/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0380 - accuracy: 0.9856 - val_loss: 0.0582 - val_accuracy: 0.9750
# Epoch 13/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0359 - accuracy: 0.9858 - val_loss: 0.0526 - val_accuracy: 0.9802
# Epoch 14/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0355 - accuracy: 0.9859 - val_loss: 0.0545 - val_accuracy: 0.9783
# Epoch 15/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0322 - accuracy: 0.9877 - val_loss: 0.0584 - val_accuracy: 0.9798
# Epoch 16/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0322 - accuracy: 0.9874 - val_loss: 0.0525 - val_accuracy: 0.9804
# Epoch 17/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0303 - accuracy: 0.9882 - val_loss: 0.0617 - val_accuracy: 0.9765
# Epoch 18/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0309 - accuracy: 0.9883 - val_loss: 0.0522 - val_accuracy: 0.9816
# Epoch 19/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0315 - accuracy: 0.9873 - val_loss: 0.0559 - val_accuracy: 0.9793
# Epoch 20/20
# 908/908 [==============================] - 2s 2ms/step - loss: 0.0257 - accuracy: 0.9902 - val_loss: 0.0523 - val_accuracy: 0.9789

# %%
def getCosineSimilarity(v1,v2):
  """
  Get cosine similarity of two numpy arrays

  Args:
      v1 (numpy array): Vector 1
      v2 (numpy array): Vector 2

  Returns:
      float: Cosine similarity value
  """
  cosine_similarity=1-spatial.distance.cosine(v1,v2)
  return round(float(cosine_similarity),3)

# %%
df=pd.read_csv("../data/scaled_music_metadata.csv",index_col=0)

# %%
def recommendSongs(trackName,numberOfSongs,df=df):
    songData=df[df.track==trackName.lower()].values.tolist()
    featureVector=np.array([songData[0][:-3]])
    songGenre=np.argmax(model.predict(featureVector)[0])
    print(songGenre)
    similarSongs=df[df.Song_Label==songGenre]
    similarSongs['similarity']=df.drop(columns=["track","artist","Song_Label"]).apply(lambda v2:getCosineSimilarity(featureVector,v2),axis=1)
    return similarSongs.sort_values(by="similarity",ascending=False).iloc[:numberOfSongs+1,:][["track","artist","similarity"]]

# %%
df
# Out:
#        danceability    energy       key  loudness      mode  speechiness  \
# 0          0.213662 -0.429547 -0.341745  0.555409  0.665000    -0.510612
# 1          0.923317  1.088968  1.355825  0.893509 -1.503759     1.274713
# 2         -2.129329  1.017601  1.072897  1.358892  0.665000    -0.297439
# 3         -1.982892  1.644038 -0.341745  1.220107  0.665000     1.077760
# 4          0.506535  0.732137 -0.907601  1.105458  0.665000    -0.526831
# ...             ...       ...       ...       ...       ...          ...
# 39998     -0.811397  0.855045  1.072897  0.781689 -1.503759     1.865573
# 39999      0.455846  0.299975  1.072897  0.741901 -1.503759    -0.487441
# 40000      0.123547 -1.052018  1.355825 -0.942377 -1.503759    -0.500185
# 40001      0.461478  0.799538  0.507040  0.779803  0.665000    -0.419086
# 40002      0.698030  0.633017 -0.907601  0.228245  0.665000    -0.541892
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0          0.009391         -0.507789 -0.245462 -0.040584  0.471364
# 1         -1.022772         -0.507789 -0.309209  0.543251 -0.905436
# 2         -1.077079         -0.492719 -0.158535 -0.908851 -1.112405
# 3         -1.077385         -0.249262 -0.054223 -0.785347  0.999746
# 4         -0.005376         -0.507789 -0.442497  0.329927 -0.248868
# ...             ...               ...       ...       ...       ...
# 39998     -1.074666         -0.507099 -0.112174  0.820198  1.154457
# 39999     -0.927972         -0.487146 -0.623884  0.550736  0.509364
# 40000      0.222025         -0.507752 -0.552604  0.105375  1.632161
# 40001     -1.077109          1.981851  1.052647 -1.230708  0.024376
# 40002     -0.764362         -0.329062  0.762891 -0.317531 -0.930552
#
#        duration_ms  time_signature  chorus_hit  sections    decade  \
# 0        -0.317757         0.25102   -0.485791  0.520170  0.987821
# 1         0.067650         0.25102    0.073128 -0.095140  0.987821
# 2         0.876650         0.25102    1.325398  0.520170  0.987821
# 3         0.177526         0.25102    0.971366 -0.300244  0.987821
# 4        -0.342512         0.25102   -0.919907 -0.095140  0.987821
# ...            ...             ...         ...       ...       ...
# 39998    -1.280432         0.25102   -0.514157 -0.915554  0.416659
# 39999    -0.192206         0.25102   -0.274722 -0.095140  0.416659
# 40000    -0.375551         0.25102   -0.999099 -0.095140  0.416659
# 40001     0.802391         0.25102    0.368848  0.109963  0.416659
# 40002     0.499308         0.25102    0.125303  0.725273  0.416659
#
#                                         track             artist  Song_Label
# 0                                   lucky man  montgomery gentry           8
# 1                              on the hotline       pretty ricky           2
# 2                          clouds of dementia         candlemass           0
# 3                    heavy metal, raise hell!      zwartketterij           0
# 4                             i got a feelin'   billy currington           8
# ...                                       ...                ...         ...
# 39998                        your secret love    luther vandross           2
# 39999             you don't know how it feels          tom petty           2
# 40000                        morning sunshine      the idle race           2
# 40001                    ya despues de muerto    chalino sanchez           0
# 40002  have yourself a merry little christmas     oscar peterson           8
#
# [38730 rows x 19 columns]

# %%
recommendSongs("master of puppets",10)
# Out:
# 8
# C:\Users\Ashwin\AppData\Local\Temp\ipykernel_4116\1072575904.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   similarSongs['similarity']=df.drop(columns=["track","artist","Song_Label"]).apply(lambda v2:getCosineSimilarity(featureVector,v2),axis=1)
#                                                    track  \
# 1131                                   master of puppets
# 3454                                       nisse på åsen
# 3056                                      punk rawk show
# 5209                                      curse the gods
# 1151                                    taking rap back
# 5468   confessions of a broken heart (daughter to fat...
# 11912                             idontwannabeyouanymore
# 2814                                            john doe
# 11655                                           shine on
# 2834                                what them girls like
# 2113                                             reason
#
#                                    artist  similarity
# 1131                             dr. know       1.000
# 3454                      göinges hjältar       0.885
# 3056                                 mxpx       0.872
# 5209                          destruction       0.869
# 1151                             funky dl       0.859
# 5468                        lindsay lohan       0.857
# 11912                       billie eilish       0.852
# 2814   public announcement featuring lele       0.847
# 11655                   the house of love       0.844
# 2834                          ludacris co       0.844
# 2113                         ian van dahl       0.843

# %%
model.save("../models/Neural_Genre_Prediction")
# Out:
# INFO:tensorflow:Assets written to: ../models/Neural_Genre_Prediction\assets
